# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabhaKusumanchi4545/CODSOFT/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 0.4325 - mean_absolute_error: 0.6344 - val_loss: 0.4206 - val_mean_absolute_error: 0.6230
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3579 - mean_absolute_error: 0.5744 - val_loss: 0.3512 - val_mean_absolute_error: 0.5661
# Epoch 3/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2973 - mean_absolute_error: 0.5215 - val_loss: 0.2965 - val_mean_absolute_error: 0.5176
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2499 - mean_absolute_error: 0.4755 - val_loss: 0.2482 - val_mean_absolute_error: 0.4704
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2051 - mean_absolute_error: 0.4274 - val_loss: 0.1999 - val_mean_absolute_error: 0.4178
# Epoch 6/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1622 - mean_absolute_error: 0.3761 - val_loss: 0.1561 - val_mean_absolute_error: 0.3643
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1246 - mean_absolute_error: 0.3255 - val_loss: 0.1189 - val_mean_absolute_error: 0.3123
# Epoch 8/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0925 - mean_absolute_error: 0.2762 - val_loss: 0.0880 - val_mean_absolute_error: 0.2619
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0664 - mean_absolute_error: 0.2285 - val_loss: 0.0629 - val_mean_absolute_error: 0.2150
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0460 - mean_absolute_error: 0.1848 - val_loss: 0.0436 - val_mean_absolute_error: 0.1730
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0309 - mean_absolute_error: 0.1470 - val_loss: 0.0298 - val_mean_absolute_error: 0.1384
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0207 - mean_absolute_error: 0.1172 - val_loss: 0.0211 - val_mean_absolute_error: 0.1151
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0150 - mean_absolute_error: 0.0971 - val_loss: 0.0162 - val_mean_absolute_error: 0.1005
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0120 - mean_absolute_error: 0.0862 - val_loss: 0.0138 - val_mean_absolute_error: 0.0931
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0816 - val_loss: 0.0126 - val_mean_absolute_error: 0.0893
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0795 - val_loss: 0.0120 - val_mean_absolute_error: 0.0878
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0098 - mean_absolute_error: 0.0782 - val_loss: 0.0117 - val_mean_absolute_error: 0.0868
# Epoch 18/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0772 - val_loss: 0.0115 - val_mean_absolute_error: 0.0855
# Epoch 19/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - mean_absolute_error: 0.0759 - val_loss: 0.0112 - val_mean_absolute_error: 0.0841
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - mean_absolute_error: 0.0746 - val_loss: 0.0105 - val_mean_absolute_error: 0.0805
# Epoch 21/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0081 - mean_absolute_error: 0.0718 - val_loss: 0.0098 - val_mean_absolute_error: 0.0767
# Epoch 22/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0691 - val_loss: 0.0092 - val_mean_absolute_error: 0.0744
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0670 - val_loss: 0.0086 - val_mean_absolute_error: 0.0726
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0653 - val_loss: 0.0082 - val_mean_absolute_error: 0.0710
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0637 - val_loss: 0.0078 - val_mean_absolute_error: 0.0695
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0622 - val_loss: 0.0075 - val_mean_absolute_error: 0.0683
# Epoch 27/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0609 - val_loss: 0.0072 - val_mean_absolute_error: 0.0671
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0055 - mean_absolute_error: 0.0593 - val_loss: 0.0070 - val_mean_absolute_error: 0.0660
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - mean_absolute_error: 0.0584 - val_loss: 0.0066 - val_mean_absolute_error: 0.0648
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - mean_absolute_error: 0.0566 - val_loss: 0.0065 - val_mean_absolute_error: 0.0638
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0048 - mean_absolute_error: 0.0551 - val_loss: 0.0062 - val_mean_absolute_error: 0.0627
# Epoch 32/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0538 - val_loss: 0.0059 - val_mean_absolute_error: 0.0615
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_absolute_error: 0.0526 - val_loss: 0.0057 - val_mean_absolute_error: 0.0604
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0513 - val_loss: 0.0055 - val_mean_absolute_error: 0.0594
# Epoch 35/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0500 - val_loss: 0.0052 - val_mean_absolute_error: 0.0583
# Epoch 36/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_absolute_error: 0.0488 - val_loss: 0.0050 - val_mean_absolute_error: 0.0572
# Epoch 37/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_absolute_error: 0.0475 - val_loss: 0.0048 - val_mean_absolute_error: 0.0560
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0464 - val_loss: 0.0046 - val_mean_absolute_error: 0.0549
# Epoch 39/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0451 - val_loss: 0.0044 - val_mean_absolute_error: 0.0537
# Epoch 40/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0043 - val_mean_absolute_error: 0.0525
# Epoch 41/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_absolute_error: 0.0428 - val_loss: 0.0041 - val_mean_absolute_error: 0.0513
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0417 - val_loss: 0.0039 - val_mean_absolute_error: 0.0503
# Epoch 43/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_absolute_error: 0.0407 - val_loss: 0.0037 - val_mean_absolute_error: 0.0490
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_absolute_error: 0.0396 - val_loss: 0.0035 - val_mean_absolute_error: 0.0479
# Epoch 45/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0385 - val_loss: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0373 - val_loss: 0.0032 - val_mean_absolute_error: 0.0455
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0367 - val_loss: 0.0030 - val_mean_absolute_error: 0.0443
# Epoch 48/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0354 - val_loss: 0.0029 - val_mean_absolute_error: 0.0431
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0343 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 50/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0339 - val_loss: 0.0026 - val_mean_absolute_error: 0.0408

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.9193866579633682
